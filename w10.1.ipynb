# %% [markdown]
# num 2 num stats

# %%
import pandas as pd
import scipy.stats as stats
url = "https://raw.githubusercontent.com/dataprofessor/data/refs/heads/master/penguins_cleaned.csv"
df = pd.read_csv(url)
df.head(2)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7                181
# 1  Adelie  Torgersen            39.5           17.4                186
#
#    body_mass_g     sex
# 0         3750    male
# 1         3800  female

# %%
df.corr(numeric_only=True)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
for col1 in df.columns:
    for col2 in df.columns:
        iscol1num = pd.api.types.is_numeric_dtype(df[col1])
        iscol2num = pd.api.types.is_numeric_dtype(df[col1])
        if col1 == col2:
            continue
        if not iscol1num or not iscol2num:
            continue
        print(col1,col2)
        r, p = stats.pearsonr(df[col1], df[col2])
        print(f"{col1}-{col2}: r={r:.3f}, p={p:.3f}")
# Out:
# bill_length_mm species
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/python-class/lib/python3.13/site-packages/scipy/_lib/array_api_compat/common/_aliases.py:669, in finfo(type_, xp)
#     668 try:
# --> 669     return xp.finfo(type_)
#     670 except (ValueError, TypeError):
#
# File ~/anaconda3/envs/python-class/lib/python3.13/site-packages/numpy/_core/getlimits.py:526, in finfo.__new__(cls, dtype)
#     525 if not issubclass(dtype, numeric.inexact):
# --> 526     raise ValueError(f"data type {dtype!r} not inexact")
#     527 obj = cls._finfo_cache.get(dtype)
#
# ValueError: data type <class 'numpy.object_'> not inexact
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 10
#       8     continue
#       9 print(col1,col2)
# ---> 10 r, p = stats.pearsonr(df[col1], df[col2])
#      11 print(f"{col1}-{col2}: r={r:.3f}, p={p:.3f}")
#
# File ~/anaconda3/envs/python-class/lib/python3.13/site-packages/scipy/stats/_stats_py.py:4700, in pearsonr(x, y, alternative, method, axis)
#    4698 x = xp.astype(x, dtype, copy=False)
#    4699 y = xp.astype(y, dtype, copy=False)
# -> 4700 threshold = xp.finfo(dtype).eps ** 0.75
#    4702 # If an input is constant, the correlation coefficient is not defined.
#    4703 const_x = xp.all(x == x[..., 0:1], axis=-1)
#
# File ~/anaconda3/envs/python-class/lib/python3.13/site-packages/scipy/_lib/array_api_compat/_internal.py:34, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      32 @wraps(f)
#      33 def wrapped_f(*args: object, **kwargs: object) -> object:
# ---> 34     return f(*args, xp=xp, **kwargs)
#
# File ~/anaconda3/envs/python-class/lib/python3.13/site-packages/scipy/_lib/array_api_compat/common/_aliases.py:671, in finfo(type_, xp)
#     669     return xp.finfo(type_)
#     670 except (ValueError, TypeError):
# --> 671     return xp.finfo(type_.dtype)
#
# AttributeError: 'numpy.dtypes.ObjectDType' object has no attribute 'dtype'

# %%
r,p = stats.pearsonr(df["body_mass_g"], df["flipper_length_mm"])
print(r,p)
r2 = r**2
print(r2)
# Out:
# 0.8729788985653616 3.1328362509712445e-105
# 0.7620921573403919

# %%
r,p = stats.pearsonr(df["body_mass_g"], df["bill_length_mm"])
print(r,p)
r2 = r**2
print(r2)
# Out:
# 0.5894511101769491 1.538613514485931e-32
# 0.34745261128883775
